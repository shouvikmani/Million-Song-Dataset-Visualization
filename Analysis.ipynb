# %%
import numpy as np
import pandas as pd
from scipy.spatial import distance
from sklearn.metrics.pairwise import cosine_similarity
import pprint, pickle
from collections import Counter

# %%
pkl_file = open('acoustic_dict.dat', 'rb')

data1 = pickle.load(pkl_file)
pprint.pprint(data1)


pkl_file.close()
# Out:
# {1954:    Genre  AVG_LOUDNESS   AVG_TEMPO  AVG_DURATION  AVG_TIMBRE1  AVG_TIMBRE2  \
# 0  blues     -9.817667  101.406833    161.688797    42.143941   -23.261274
# 1   jazz     -9.695750  110.539500    274.631382    42.636035   -27.971574
# 2    pop    -10.417000  109.915000    142.458320    41.375167     3.707051
#
#    AVG_TIMBRE3  AVG_TIMBRE4  AVG_TIMBRE5  AVG_TIMBRE6        ...         \
# 0    30.801986     4.675259   -15.200846    15.814974        ...
# 1    36.895586     7.718925    -4.966637     9.977259        ...
# 2    -3.114153   -14.012391    17.744147    13.555640        ...
#
#    AVG_VAR_TIMBRE3  AVG_VAR_TIMBRE4  AVG_VAR_TIMBRE5  AVG_VAR_TIMBRE6  \
# 0      2112.018966      3049.206799      1084.271976      1187.028193
# 1      3108.637698      2707.599183       984.578411      1215.337745
# 2      2330.298542      3124.232335      1004.295674      1349.771781
#
#    AVG_VAR_TIMBRE7  AVG_VAR_TIMBRE8  AVG_VAR_TIMBRE9  AVG_VAR_TIMBRE10  \
# ...

# %%
data1[2010].columns
# Out:
# Index([u'Genre', u'AVG_LOUDNESS', u'AVG_TEMPO', u'AVG_DURATION',
#        u'AVG_TIMBRE1', u'AVG_TIMBRE2', u'AVG_TIMBRE3', u'AVG_TIMBRE4',
#        u'AVG_TIMBRE5', u'AVG_TIMBRE6', u'AVG_TIMBRE7', u'AVG_TIMBRE8',
#        u'AVG_TIMBRE9', u'AVG_TIMBRE10', u'AVG_TIMBRE11', u'AVG_TIMBRE12',
#        u'AVG_VAR_TIMBRE1', u'AVG_VAR_TIMBRE2', u'AVG_VAR_TIMBRE3',
#        u'AVG_VAR_TIMBRE4', u'AVG_VAR_TIMBRE5', u'AVG_VAR_TIMBRE6',
#        u'AVG_VAR_TIMBRE7', u'AVG_VAR_TIMBRE8', u'AVG_VAR_TIMBRE9',
#        u'AVG_VAR_TIMBRE10', u'AVG_VAR_TIMBRE11', u'AVG_VAR_TIMBRE12'],
#       dtype='object')

# %%
data1[2010]
# Out:
#         Genre  AVG_LOUDNESS   AVG_TEMPO  AVG_DURATION  AVG_TIMBRE1  \
# 0       blues    -10.363000  104.422750    217.808527    41.187659
# 1     country    -11.586500  138.496500    264.293425    40.533458
# 2  electronic     -6.470295  123.936545    273.650011    45.564966
# 3     hip-hop     -7.305000  163.667000    289.697510    44.194332
# 4       indie     -8.092781  129.961031    218.948118    44.300200
# 5        jazz    -14.385727  128.437364    382.900030    38.018709
# 6         pop     -5.315455  128.013576    221.478334    48.353268
# 7         rap     -8.052000   91.836000    366.654240    39.810385
# 8        rock     -6.298000  136.215543    231.794486    47.507412
#
#    AVG_TIMBRE2  AVG_TIMBRE3  AVG_TIMBRE4  AVG_TIMBRE5  AVG_TIMBRE6  \
# 0   -32.881135    22.445849     3.258988   -13.971576    -4.254380
# 1   -80.843704     8.074077    -4.828266    17.850283   -11.407415
# 2    12.218464    -5.348102    17.413145     1.275553   -11.859623
# ...

# %%
data_2010 = data1[2010]

# %%
data_2010.loc[:,"AVG_LOUDNESS"]
# Out:
# 0   -10.363000
# 1   -11.586500
# 2    -6.470295
# 3    -7.305000
# 4    -8.092781
# 5   -14.385727
# 6    -5.315455
# 7    -8.052000
# 8    -6.298000
# Name: AVG_LOUDNESS, dtype: float64

# %%
data_2010.columns[1:]
# Out:
# Index([u'AVG_LOUDNESS', u'AVG_TEMPO', u'AVG_DURATION', u'AVG_TIMBRE1',
#        u'AVG_TIMBRE2', u'AVG_TIMBRE3', u'AVG_TIMBRE4', u'AVG_TIMBRE5',
#        u'AVG_TIMBRE6', u'AVG_TIMBRE7', u'AVG_TIMBRE8', u'AVG_TIMBRE9',
#        u'AVG_TIMBRE10', u'AVG_TIMBRE11', u'AVG_TIMBRE12', u'AVG_VAR_TIMBRE1',
#        u'AVG_VAR_TIMBRE2', u'AVG_VAR_TIMBRE3', u'AVG_VAR_TIMBRE4',
#        u'AVG_VAR_TIMBRE5', u'AVG_VAR_TIMBRE6', u'AVG_VAR_TIMBRE7',
#        u'AVG_VAR_TIMBRE8', u'AVG_VAR_TIMBRE9', u'AVG_VAR_TIMBRE10',
#        u'AVG_VAR_TIMBRE11', u'AVG_VAR_TIMBRE12'],
#       dtype='object')

# %%
data_2010_norm = data_2010.copy()
sel_cols = data_2010.columns[1:]
for col in sel_cols:
    feature = data_2010.loc[:,col]
    data_2010_norm.loc[:,col] = (feature - np.mean(feature))/ np.std(feature)
    print data_2010_norm.loc[:,col]
# Out:
# 0   -0.620908
# 1   -1.064929
# 2    0.791793
# 3    0.488870
# 4    0.202977
# 5   -2.080796
# 6    1.210896
# 7    0.217777
# 8    0.854321
# Name: AVG_LOUDNESS, dtype: float64
# 0   -1.185456
# 1    0.586323
# 2   -0.170771
# 3    1.895148
# 4    0.142493
# 5    0.063264
# 6    0.041228
# 7   -1.839947
# 8    0.467717
# Name: AVG_TEMPO, dtype: float64
# 0   -0.951918
# 1   -0.166338
# 2   -0.008214
# 3    0.262984
# 4   -0.932660
# 5    1.838078
# 6   -0.889900
# 7    1.563529
# 8   -0.715560
# Name: AVG_DURATION, dtype: float64
# 0   -0.618827
# 1   -0.812824
# 2    0.679217
# 3    0.272770
# 4    0.304164
# 5   -1.558547
# 6    1.506060
# 7   -1.027244
# 8    1.255230
# Name: AVG_TIMBRE1, dtype: float64
# 0   -0.441514
# 1   -2.003334
# 2    1.027078
# 3   -0.431728
# 4   -0.051405
# 5   -0.873416
# 6    1.250631
# 7    0.588568
# 8    0.935120
# Name: AVG_TIMBRE2, dtype: float64
# 0    1.458533
# 1    0.756150
# 2    0.100175
# 3   -1.230019
# 4   -0.019236
# 5   -0.867256
# ...

# %%
data_2010_norm
# Out:
#         Genre  AVG_LOUDNESS  AVG_TEMPO  AVG_DURATION  AVG_TIMBRE1  \
# 0       blues     -0.620908  -1.185456     -0.951918    -0.618827
# 1     country     -1.064929   0.586323     -0.166338    -0.812824
# 2  electronic      0.791793  -0.170771     -0.008214     0.679217
# 3     hip-hop      0.488870   1.895148      0.262984     0.272770
# 4       indie      0.202977   0.142493     -0.932660     0.304164
# 5        jazz     -2.080796   0.063264      1.838078    -1.558547
# 6         pop      1.210896   0.041228     -0.889900     1.506060
# 7         rap      0.217777  -1.839947      1.563529    -1.027244
# 8        rock      0.854321   0.467717     -0.715560     1.255230
#
#    AVG_TIMBRE2  AVG_TIMBRE3  AVG_TIMBRE4  AVG_TIMBRE5  AVG_TIMBRE6  \
# 0    -0.441514     1.458533     0.426687    -1.232193     0.874965
# 1    -2.003334     0.756150    -0.677896     1.427797    -0.479428
# 2     1.027078     0.100175     2.359907     0.042315    -0.565052
# ...

# %%
data1[2010]
# Out:
#         Genre  AVG_LOUDNESS   AVG_TEMPO  AVG_DURATION  AVG_TIMBRE1  \
# 0       blues    -10.363000  104.422750    217.808527    41.187659
# 1     country    -11.586500  138.496500    264.293425    40.533458
# 2  electronic     -6.470295  123.936545    273.650011    45.564966
# 3     hip-hop     -7.305000  163.667000    289.697510    44.194332
# 4       indie     -8.092781  129.961031    218.948118    44.300200
# 5        jazz    -14.385727  128.437364    382.900030    38.018709
# 6         pop     -5.315455  128.013576    221.478334    48.353268
# 7         rap     -8.052000   91.836000    366.654240    39.810385
# 8        rock     -6.298000  136.215543    231.794486    47.507412
#
#    AVG_TIMBRE2  AVG_TIMBRE3  AVG_TIMBRE4  AVG_TIMBRE5  AVG_TIMBRE6  \
# 0   -32.881135    22.445849     3.258988   -13.971576    -4.254380
# 1   -80.843704     8.074077    -4.828266    17.850283   -11.407415
# 2    12.218464    -5.348102    17.413145     1.275553   -11.859623
# ...

# %%
data_2010_norm.loc[data_2010_norm.loc[:,"Genre"]=="rock",:]
# Out:
#   Genre  AVG_LOUDNESS  AVG_TEMPO  AVG_DURATION  AVG_TIMBRE1  AVG_TIMBRE2  \
# 8  rock      0.854321   0.467717      -0.71556      1.25523      0.93512
#
#    AVG_TIMBRE3  AVG_TIMBRE4  AVG_TIMBRE5  AVG_TIMBRE6        ...         \
# 8     0.719189    -0.306727    -1.537602    -1.493907        ...
#
#    AVG_VAR_TIMBRE3  AVG_VAR_TIMBRE4  AVG_VAR_TIMBRE5  AVG_VAR_TIMBRE6  \
# 8        -1.221863        -0.877625        -1.894458        -0.873663
#
#    AVG_VAR_TIMBRE7  AVG_VAR_TIMBRE8  AVG_VAR_TIMBRE9  AVG_VAR_TIMBRE10  \
# 8        -1.204663        -0.737135        -1.806516          -1.02525
#
#    AVG_VAR_TIMBRE11  AVG_VAR_TIMBRE12
# 8         -1.027445          -1.19218
#
# [1 rows x 28 columns]

# %%
data_2010_norm = data_2010_norm.set_index('Genre')

# %%
data_2010_norm.loc["rock",].values - data_2010_norm.loc["country",:].values
# Out:
# array([  1.91924906e+00,  -1.18606051e-01,  -5.49222218e-01,
#          2.06805367e+00,   2.93845462e+00,  -3.69609841e-02,
#          3.71168356e-01,  -2.96539930e+00,  -1.01447925e+00,
#          1.19290780e+00,   1.17755935e+00,  -1.90859723e-01,
#          1.99075188e+00,  -4.86803399e-01,   6.80995240e-01,
#         -2.14582549e+00,  -5.60786184e-01,  -2.36807032e+00,
#         -2.01850365e-01,  -2.12991893e+00,   3.72443912e-01,
#         -6.90222062e-01,   1.42938009e-01,  -3.79842698e+00,
#          4.30287523e-03,  -2.90138406e-03,  -1.41255444e-01])

# %%
data_2010_norm.loc["rock",].values - data_2010_norm.loc["jazz",:].values
# Out:
# array([ 2.93511638,  0.40445263, -2.55363789,  2.81377637,  1.80853652,
#         1.58644497,  1.29024627, -2.74643896, -1.31292171,  0.89340938,
#         0.42443459,  0.40177516,  0.00513352,  1.11734191, -0.05582614,
#         0.21808925, -1.68871931, -1.11543821, -0.45234596, -2.28683008,
#        -0.25278636, -1.39411522, -0.46378047, -1.92554   , -1.30482828,
#        -0.60334436, -1.52916243])

# %%
distance.cosine(data_2010_norm.loc["rock",].values,data_2010_norm.loc["country",:].values)
# Out:
# 1.1069943789155872

# %%
distance.cosine(data_2010_norm.loc["rock",].values,data_2010_norm.loc["jazz",:].values)
# Out:
# 1.2426069007020719

# %%
sim = cosine_similarity(data_2010_norm.as_matrix())

# %%
print sim
# Out:
# [[  1.00000000e+00   1.69245622e-01  -1.77670744e-01  -1.00689231e-02
#     3.82510292e-02  -3.31112329e-01  -1.52494608e-01  -3.00916401e-01
#    -7.94542311e-02]
#  [  1.69245622e-01   1.00000000e+00  -3.62110724e-01  -2.56371584e-01
#     6.99745996e-02   3.00633156e-01  -1.49690385e-01  -4.51067645e-01
#    -1.06994379e-01]
#  [ -1.77670744e-01  -3.62110724e-01   1.00000000e+00  -1.04375739e-01
#     2.58275530e-04  -2.29178989e-01  -2.00510275e-02   4.89835926e-02
#    -1.01833951e-01]
#  [ -1.00689231e-02  -2.56371584e-01  -1.04375739e-01   1.00000000e+00
#    -4.27296352e-01  -1.80312924e-01  -5.03073700e-01   3.71218694e-01
#    -5.09131327e-01]
#  [  3.82510292e-02   6.99745996e-02   2.58275530e-04  -4.27296352e-01
#     1.00000000e+00  -2.39823898e-01   2.91301383e-01  -3.57837154e-01
#     3.35639423e-01]
#  [ -3.31112329e-01   3.00633156e-01  -2.29178989e-01  -1.80312924e-01
#    -2.39823898e-01   1.00000000e+00  -2.87979222e-01   8.88788219e-02
#    -2.42606901e-01]
# ...

# %%
data_2010
# Out:
#         Genre  AVG_LOUDNESS   AVG_TEMPO  AVG_DURATION  AVG_TIMBRE1  \
# 0       blues    -10.363000  104.422750    217.808527    41.187659
# 1     country    -11.586500  138.496500    264.293425    40.533458
# 2  electronic     -6.470295  123.936545    273.650011    45.564966
# 3     hip-hop     -7.305000  163.667000    289.697510    44.194332
# 4       indie     -8.092781  129.961031    218.948118    44.300200
# 5        jazz    -14.385727  128.437364    382.900030    38.018709
# 6         pop     -5.315455  128.013576    221.478334    48.353268
# 7         rap     -8.052000   91.836000    366.654240    39.810385
# 8        rock     -6.298000  136.215543    231.794486    47.507412
#
#    AVG_TIMBRE2  AVG_TIMBRE3  AVG_TIMBRE4  AVG_TIMBRE5  AVG_TIMBRE6  \
# 0   -32.881135    22.445849     3.258988   -13.971576    -4.254380
# 1   -80.843704     8.074077    -4.828266    17.850283   -11.407415
# 2    12.218464    -5.348102    17.413145     1.275553   -11.859623
# ...

# %%
data_2010_norm = data_2010_norm.T

# %%
data_2010_norm.corr()
# Out:
# Genre          blues   country  electronic   hip-hop     indie      jazz  \
# Genre
# blues       1.000000  0.159167   -0.174268  0.008946  0.026715 -0.361152
# country     0.159167  1.000000   -0.262431 -0.188089  0.015805  0.245343
# electronic -0.174268 -0.262431    1.000000 -0.353165  0.140300 -0.098259
# hip-hop     0.008946 -0.188089   -0.353165  1.000000 -0.391755 -0.106252
# indie       0.026715  0.015805    0.140300 -0.391755  1.000000 -0.311699
# jazz       -0.361152  0.245343   -0.098259 -0.106252 -0.311699  1.000000
# pop        -0.180166 -0.255643    0.194953 -0.450672  0.245773 -0.404859
# rap        -0.300109 -0.392640   -0.201375  0.292233 -0.311743  0.207851
# rock       -0.118390 -0.263661    0.197270 -0.436739  0.280458 -0.418139
#
# Genre            pop       rap      rock
# Genre
# blues      -0.180166 -0.300109 -0.118390
# country    -0.255643 -0.392640 -0.263661
# electronic  0.194953 -0.201375  0.197270
# hip-hop    -0.450672  0.292233 -0.436739
# ...

# %%
pkl_file = open('acoustic_dict_withRE.dat', 'rb')
data_re = pickle.load(pkl_file)

# %%
data_re[1960]
# Out:
#    Genre  AVG_LOUDNESS   AVG_TEMPO  AVG_DURATION  AVG_TIMBRE1  AVG_TIMBRE2  \
# 0  blues    -12.427024  119.694548    157.604989    40.182073   -66.614314
# 1   jazz    -13.389583  110.165917    146.359274    38.547846   -88.631443
# 2    pop    -14.150962  118.958500    152.690283    38.980431   -28.113917
# 3   rock    -10.119040  137.877840    151.867103    44.875156   -10.068696
#
#    AVG_TIMBRE3  AVG_TIMBRE4  AVG_TIMBRE5  AVG_TIMBRE6        ...         \
# 0    24.427477    -0.356422    -1.444050     3.386572        ...
# 1    11.084907    -4.551399   -10.374355     0.716543        ...
# 2    13.427318     1.378150   -12.146588    -0.310159        ...
# 3    51.128450     7.276257    -1.826623    -3.227041        ...
#
#    AVG_VAR_TIMBRE3  AVG_VAR_TIMBRE4  AVG_VAR_TIMBRE5  AVG_VAR_TIMBRE6  \
# 0      2929.308991      2027.083450       875.726334      1047.861955
# 1      2567.327211      2068.213107       939.785736       987.140846
# ...

# %%
pkl_file = open('pivot_dict_withRE.dat', 'rb')
data_re_pivot = pickle.load(pkl_file)

# %%
data_re[2010]
# Out:
#         Genre  AVG_LOUDNESS   AVG_TEMPO  AVG_DURATION  AVG_TIMBRE1  \
# 0       blues    -11.434200  123.277467    280.575547    39.359355
# 1     country    -10.012286  123.788714    239.747651    42.008341
# 2  electronic     -7.104092  122.407723    276.416049    44.821210
# 3     hip-hop     -7.305000  163.667000    289.697510    44.194332
# 4       indie     -7.688889  135.049889    216.244497    44.878004
# 5        jazz    -13.807954  126.624123    353.701928    38.185779
# 6         pop     -5.367212  127.973871    218.227870    47.802826
# 7         rap     -9.548000  109.584500    467.081995    41.456370
# 8        rock     -6.922125  132.017652    224.168643    46.399491
#
#    AVG_TIMBRE2  AVG_TIMBRE3  AVG_TIMBRE4  AVG_TIMBRE5  AVG_TIMBRE6  \
# 0   -59.906300    -0.992845     1.261166    -2.044179    -6.451194
# 1   -50.110370     2.998282    -7.030868     5.124506    -8.031133
# 2    13.264266    -7.725192    18.080795     3.099757   -11.271434
# ...

# %%
acoustic_df = pd.read_table('msd_genre_dataset.txt', sep = ',')
acoustic_df.head()
# Out:
#                   genre            track_id       artist_name  \
# 0  classic pop and rock  TRFCOOU128F427AEC0  Blue Oyster Cult
# 1  classic pop and rock  TRNJTPB128F427AE9F  Blue Oyster Cult
# 2  classic pop and rock  TRLFJHA128F427AEEA  Blue Oyster Cult
# 3  classic pop and rock  TRCQZAG128F427DB97  Blue Oyster Cult
# 4  classic pop and rock  TRNXMNM128F427DB8C  Blue Oyster Cult
#
#                      title  loudness    tempo  time_signature  key  mode  \
# 0          Mes Dames Sarat    -8.697  155.007               1    9     1
# 1                  Screams   -10.659  148.462               1    4     0
# 2     Dance The Night Away   -13.494  112.909               1   10     0
# 3            Debbie Denise   -12.786  117.429               4    7     1
# 4  (Don't Fear) The Reaper   -14.093  141.536               4    9     0
#
#     duration      ...       var_timbre3  var_timbre4  var_timbre5  \
# 0  246.33424      ...       1255.514569   580.030472   598.485223
# ...

# %%
acoustic_df.shape
# Out:
# (59600, 34)

# %%
set(acoustic_df['genre'])
# Out:
# {'classic pop and rock',
#  'classical',
#  'dance and electronica',
#  'folk',
#  'hip-hop',
#  'jazz and blues',
#  'metal',
#  'pop',
#  'punk',
#  'soul and reggae'}

# %%
Counter(acoustic_df['genre'])
# Out:
# Counter({'classic pop and rock': 23895,
#          'classical': 1874,
#          'dance and electronica': 4935,
#          'folk': 13192,
#          'hip-hop': 434,
#          'jazz and blues': 4334,
#          'metal': 2103,
#          'pop': 1617,
#          'punk': 3200,
#          'soul and reggae': 4016})

# %%
acoustic_df.columns
# Out:
# Index([u'genre', u'track_id', u'artist_name', u'title', u'loudness', u'tempo',
#        u'time_signature', u'key', u'mode', u'duration', u'avg_timbre1',
#        u'avg_timbre2', u'avg_timbre3', u'avg_timbre4', u'avg_timbre5',
#        u'avg_timbre6', u'avg_timbre7', u'avg_timbre8', u'avg_timbre9',
#        u'avg_timbre10', u'avg_timbre11', u'avg_timbre12', u'var_timbre1',
#        u'var_timbre2', u'var_timbre3', u'var_timbre4', u'var_timbre5',
#        u'var_timbre6', u'var_timbre7', u'var_timbre8', u'var_timbre9',
#        u'var_timbre10', u'var_timbre11', u'var_timbre12'],
#       dtype='object')

# %%
data_re_pivot[1954]
# Out:
#      Genre  Blues  Country  Electronic  HipHop  Indie  Jazz  Pop  Rap  Rock
# 0    blues     51        4           0       0      0    19   25    0    30
# 1  country      4        7           0       0      0     0    6    0     6
# 2     jazz     19        0           0       0      0    50   17    0    11
# 3      pop     25        6           0       0      0    17   53    0    30
# 4     rock     30        6           0       0      0    11   30    0    38

# %%
data_re_pivot[1955]
# Out:
#         Genre  Blues  Country  Electronic  HipHop  Indie  Jazz  Pop  Rap  Rock
# 0       blues     79       14           1       0      0    39   39    0    49
# 1     country     14       19           0       0      0    14    9    0     9
# 2  electronic      1        0           1       0      0     1    0    0     0
# 3     hip-hop      0        0           0       3      0     3    0    0     0
# 4       indie      0        0           0       0      1     0    1    0     1
# 5        jazz     39       14           1       3      0   134   43    0    27
# 6         pop     39        9           0       0      1    43   77    0    38
# 7        rock     49        9           0       0      1    27   38    0    61

# %%
data_re_pivot[1957]
# Out:
#         Genre  Blues  Country  Electronic  HipHop  Indie  Jazz  Pop  Rap  Rock
# 0       blues    205       33           3       0      0    92  100    5   143
# 1     country     33       73           0       0      1     6   33    0    50
# 2  electronic      3        0           3       0      0     0    3    0     3
# 3     hip-hop      0        0           0       4      0     4    0    4     4
# 4       indie      0        1           0       0      1     1    1    0     0
# 5        jazz     92        6           0       4      1   238   68    7    64
# 6         pop    100       33           3       0      1    68  174    2   129
# 7         rap      5        0           0       4      0     7    2   10     9
# 8        rock    143       50           3       4      0    64  129    9   217

# %%
data_re_pivot[2000]
# Out:
#         Genre  Blues  Country  Electronic  HipHop  Indie  Jazz   Pop  Rap  \
# 0       blues    550       47          33      53     50   140   160   46
# 1     country     47      550          15      11     92    21   139   21
# 2  electronic     33       15        1576     123    245   372   509  119
# 3     hip-hop     53       11         123     649     70   118   158  389
# 4       indie     50       92         245      70   1229   112   669  105
# 5        jazz    140       21         372     118    112  1531   269  113
# 6         pop    160      139         509     158    669   269  2667  177
# 7         rap     46       21         119     389    105   113   177  751
# 8        rock    223      198         468     163    909   305  1422  277
#
#    Rock
# 0   223
# 1   198
# 2   468
# 3   163
# 4   909
# 5   305
# 6  1422
# 7   277
# 8  4323

# %%
data1[2010]
# Out:
#         Genre  AVG_LOUDNESS   AVG_TEMPO  AVG_DURATION  AVG_TIMBRE1  \
# 0       blues    -10.363000  104.422750    217.808527    41.187659
# 1     country    -11.586500  138.496500    264.293425    40.533458
# 2  electronic     -6.470295  123.936545    273.650011    45.564966
# 3     hip-hop     -7.305000  163.667000    289.697510    44.194332
# 4       indie     -8.092781  129.961031    218.948118    44.300200
# 5        jazz    -14.385727  128.437364    382.900030    38.018709
# 6         pop     -5.315455  128.013576    221.478334    48.353268
# 7         rap     -8.052000   91.836000    366.654240    39.810385
# 8        rock     -6.298000  136.215543    231.794486    47.507412
#
#    AVG_TIMBRE2  AVG_TIMBRE3  AVG_TIMBRE4  AVG_TIMBRE5  AVG_TIMBRE6  \
# 0   -32.881135    22.445849     3.258988   -13.971576    -4.254380
# 1   -80.843704     8.074077    -4.828266    17.850283   -11.407415
# 2    12.218464    -5.348102    17.413145     1.275553   -11.859623
# ...

# %%
from scipy import spatial

dataSetI = [3, 45, 7, 2]
dataSetII = [2, 54, 13, 15]
result = 1 - spatial.distance.cosine(dataSetI, dataSetII)

# %%
result
# Out:
# 0.97228425171234989

# %%
1 - spatial.distance.cosine(data_2010_norm["rock"],data_2010_norm["pop"])
# Out:
# 0.90360762673599626

# %%
1 - spatial.distance.cosine(data_2010_norm["rock"],data_2010_norm["hip-hop"])
# Out:
# -0.50913132708624875

# %%
1 - spatial.distance.cosine(data_2010_norm["rock"],data_2010_norm["indie"])
# Out:
# 0.33563942279481918

# %%
1 - spatial.distance.cosine(data_2010_norm["country"],data_2010_norm["electronic"])
# Out:
# -0.36211072426824131

# %%
1 - spatial.distance.cosine(data_2010_norm["pop"],data_2010_norm["electronic"])
# Out:
# -0.020051027505932906

# %%
1 - spatial.distance.cosine(data_2010_norm["indie"],data_2010_norm["electronic"])
# Out:
# 0.00025827553040314033

# %%
data_re_pivot[2010]
# Out:
#         Genre  Blues  Country  Electronic  HipHop  Indie  Jazz   Pop  Rap  \
# 0       blues    149        2          16      14     31    19    38    8
# 1     country      2      126           2       0     31     0    25    0
# 2  electronic     16        2         921      66    343    82   397   44
# 3     hip-hop     14        0          66     201     24    10    55   65
# 4       indie     31       31         343      24   1180    30   600   35
# 5        jazz     19        0          82      10     30   311    76    7
# 6         pop     38       25         397      55    600    76  1236   65
# 7         rap      8        0          44      65     35     7    65  130
# 8        rock     80       44         276      27    725    49   598   45
#
#    Rock
# 0    80
# 1    44
# 2   276
# 3    27
# 4   725
# 5    49
# 6   598
# 7    45
# 8  1749
