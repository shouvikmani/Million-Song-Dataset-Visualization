# %%
import pandas as pd
import sqlite3

#read file
acoustic_df = pd.read_table('msd_genre_dataset.txt', sep = ',')
acoustic_df.head()
# Out:
#                   genre            track_id       artist_name  \
# 0  classic pop and rock  TRFCOOU128F427AEC0  Blue Oyster Cult
# 1  classic pop and rock  TRNJTPB128F427AE9F  Blue Oyster Cult
# 2  classic pop and rock  TRLFJHA128F427AEEA  Blue Oyster Cult
# 3  classic pop and rock  TRCQZAG128F427DB97  Blue Oyster Cult
# 4  classic pop and rock  TRNXMNM128F427DB8C  Blue Oyster Cult
#
#                      title  loudness    tempo  time_signature  key  mode  \
# 0          Mes Dames Sarat    -8.697  155.007               1    9     1
# 1                  Screams   -10.659  148.462               1    4     0
# 2     Dance The Night Away   -13.494  112.909               1   10     0
# 3            Debbie Denise   -12.786  117.429               4    7     1
# 4  (Don't Fear) The Reaper   -14.093  141.536               4    9     0
#
#     duration      ...       var_timbre3  var_timbre4  var_timbre5  \
# 0  246.33424      ...       1255.514569   580.030472   598.485223
# 1  189.80526      ...       2007.653070  1043.474073   585.694981
# 2  158.19710      ...       1204.856777  2736.520024   730.233239
# 3  250.22649      ...        809.755802   563.908070   492.803819
# 4  307.06893      ...       1093.684935   343.556047   889.163314
#
#    var_timbre6  var_timbre7  var_timbre8  var_timbre9  var_timbre10  \
# 0   575.337671   322.068603   321.726029   232.700609    186.805303
# 1   564.013736   510.177022   400.200186   365.119588    238.099708
# 2   665.203452   535.775111   439.335059   486.822970    265.333860
# 3   378.382799   372.875044   231.941957   246.313305    168.400152
# 4   218.111796   304.862864   178.352161   440.478867    142.669283
#
#    var_timbre11  var_timbre12
# 0    181.938688    151.508011
# 1    197.933757    251.577525
# 2    447.097987    251.880724
# 3     85.282462    339.897173
# 4     81.061326    208.355152
#
# [5 rows x 34 columns]

# %%
selected_columns = [u'track_id', u'loudness', u'tempo',
       u'time_signature', u'key', u'mode', u'duration', u'avg_timbre1',
       u'avg_timbre2', u'avg_timbre3', u'avg_timbre4', u'avg_timbre5',
       u'avg_timbre6', u'avg_timbre7', u'avg_timbre8', u'avg_timbre9',
       u'avg_timbre10', u'avg_timbre11', u'avg_timbre12', u'var_timbre1',
       u'var_timbre2', u'var_timbre3', u'var_timbre4', u'var_timbre5',
       u'var_timbre6', u'var_timbre7', u'var_timbre8', u'var_timbre9',
       u'var_timbre10', u'var_timbre11', u'var_timbre12']
df_selcol = acoustic_df[selected_columns]
df_selcol.columns
# Out:
# Index([u'track_id', u'loudness', u'tempo', u'time_signature', u'key', u'mode',
#        u'duration', u'avg_timbre1', u'avg_timbre2', u'avg_timbre3',
#        u'avg_timbre4', u'avg_timbre5', u'avg_timbre6', u'avg_timbre7',
#        u'avg_timbre8', u'avg_timbre9', u'avg_timbre10', u'avg_timbre11',
#        u'avg_timbre12', u'var_timbre1', u'var_timbre2', u'var_timbre3',
#        u'var_timbre4', u'var_timbre5', u'var_timbre6', u'var_timbre7',
#        u'var_timbre8', u'var_timbre9', u'var_timbre10', u'var_timbre11',
#        u'var_timbre12'],
#       dtype='object')

# %%
df_selcol.head()
# Out:
#              track_id  loudness    tempo  time_signature  key  mode  \
# 0  TRFCOOU128F427AEC0    -8.697  155.007               1    9     1
# 1  TRNJTPB128F427AE9F   -10.659  148.462               1    4     0
# 2  TRLFJHA128F427AEEA   -13.494  112.909               1   10     0
# 3  TRCQZAG128F427DB97   -12.786  117.429               4    7     1
# 4  TRNXMNM128F427DB8C   -14.093  141.536               4    9     0
#
#     duration  avg_timbre1  avg_timbre2  avg_timbre3      ...       \
# 0  246.33424    46.673067    14.613684    14.664215      ...
# 1  189.80526    43.645377   -87.337150    41.051582      ...
# 2  158.19710    37.573538   -61.202030    28.760533      ...
# 3  250.22649    42.566615    17.217897    53.484213      ...
# 4  307.06893    40.976507   -13.609779    39.566169      ...
#
#    var_timbre3  var_timbre4  var_timbre5  var_timbre6  var_timbre7  \
# 0  1255.514569   580.030472   598.485223   575.337671   322.068603
# 1  2007.653070  1043.474073   585.694981   564.013736   510.177022
# 2  1204.856777  2736.520024   730.233239   665.203452   535.775111
# 3   809.755802   563.908070   492.803819   378.382799   372.875044
# 4  1093.684935   343.556047   889.163314   218.111796   304.862864
#
#    var_timbre8  var_timbre9  var_timbre10  var_timbre11  var_timbre12
# 0   321.726029   232.700609    186.805303    181.938688    151.508011
# 1   400.200186   365.119588    238.099708    197.933757    251.577525
# 2   439.335059   486.822970    265.333860    447.097987    251.880724
# 3   231.941957   246.313305    168.400152     85.282462    339.897173
# 4   178.352161   440.478867    142.669283     81.061326    208.355152
#
# [5 rows x 31 columns]

# %% [markdown]
# Insert into SQL database

# %%
#Function taken from http://yznotes.com/write-pandas-dataframe-to-sqlite/
def df2sqlite(dataframe, db_name, tbl_name):
    conn=sqlite3.connect(db_name)
    conn.text_factory = lambda x: unicode(x, "utf-8", "ignore")    
    cur = conn.cursor()                                 
 
    wildcards = ','.join(['?'] * len(dataframe.columns))    
    data = [tuple(x) for x in dataframe.values]

    cur.execute("drop table if exists %s" % tbl_name)
 
    col_str = '"' + '","'.join(dataframe.columns) + '"'
    cur.execute("create table %s (%s)" % (tbl_name, col_str))
 
    cur.executemany("insert into %s values(%s)" % (tbl_name, wildcards), data)
 
    conn.commit()
    conn.close()

# %%
_DBName = '../../MillionSongSubset/lastfm_tags.db'
_TableName = u'track_acoustic'

# %%
df2sqlite(df_selcol, db_name = _DBName, tbl_name = _TableName)

# %%
# See the tables
conn=sqlite3.connect(_DBName)
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
#conn.close()
# Out:
# [(u'tags',), (u'tids',), (u'tid_tag',), (u'track_year',), (u'track_acoustic',), (u'track_genre_clean',)]

# %%
# Confirm that the data is there
df = pd.read_sql_query("SELECT * FROM track_acoustic LIMIT 5", conn)
df.head()
# Out:
#              track_id  loudness    tempo  time_signature  key  mode  \
# 0  TRFCOOU128F427AEC0    -8.697  155.007               1    9     1
# 1  TRNJTPB128F427AE9F   -10.659  148.462               1    4     0
# 2  TRLFJHA128F427AEEA   -13.494  112.909               1   10     0
# 3  TRCQZAG128F427DB97   -12.786  117.429               4    7     1
# 4  TRNXMNM128F427DB8C   -14.093  141.536               4    9     0
#
#     duration  avg_timbre1  avg_timbre2  avg_timbre3      ...       \
# 0  246.33424    46.673067    14.613684    14.664215      ...
# 1  189.80526    43.645377   -87.337150    41.051582      ...
# 2  158.19710    37.573538   -61.202030    28.760533      ...
# 3  250.22649    42.566615    17.217897    53.484213      ...
# 4  307.06893    40.976507   -13.609779    39.566169      ...
#
#    var_timbre3  var_timbre4  var_timbre5  var_timbre6  var_timbre7  \
# 0  1255.514569   580.030472   598.485223   575.337671   322.068603
# 1  2007.653070  1043.474073   585.694981   564.013736   510.177022
# 2  1204.856777  2736.520024   730.233239   665.203452   535.775111
# 3   809.755802   563.908070   492.803819   378.382799   372.875044
# 4  1093.684935   343.556047   889.163314   218.111796   304.862864
#
#    var_timbre8  var_timbre9  var_timbre10  var_timbre11  var_timbre12
# 0   321.726029   232.700609    186.805303    181.938688    151.508011
# 1   400.200186   365.119588    238.099708    197.933757    251.577525
# 2   439.335059   486.822970    265.333860    447.097987    251.880724
# 3   231.941957   246.313305    168.400152     85.282462    339.897173
# 4   178.352161   440.478867    142.669283     81.061326    208.355152
#
# [5 rows x 31 columns]

# %%
#Number of rows
df = pd.read_sql_query("SELECT COUNT(*) FROM track_acoustic", conn)
-df.head()
# Out:
#    COUNT(*)
# 0     59600

# %%
join_statement = 'tid_tag JOIN tids ON (tid_tag.tid=tids.ROWID) JOIN \
tags ON (tags.ROWID=tid_tag.tag) JOIN track_year ON (tids.tid = track_year.tid) JOIN track_acoustic ta ON(tids.tid = ta.track_id)'

drop_view = "DROP VIEW genre_view;"

cursor.execute(drop_view)

query_genres = "CREATE VIEW genre_view AS \
SELECT CASE \
WHEN LOWER(tags.tag) LIKE '%rock%' THEN 'rock' \
WHEN LOWER(tags.tag) LIKE '%pop%' THEN 'pop' \
WHEN LOWER(tags.tag) LIKE '%country%' THEN 'country' \
WHEN LOWER(tags.tag) LIKE '%jazz%' THEN 'jazz' \
WHEN LOWER(tags.tag) LIKE '%blues%' THEN 'blues' \
WHEN LOWER(tags.tag) LIKE '%electronic%' THEN 'electronic' \
WHEN LOWER(tags.tag) LIKE '%indie%' THEN 'indie' \
WHEN LOWER(tags.tag) LIKE '%hip-hop%' THEN 'hip-hop' \
WHEN LOWER(tags.tag) LIKE '%hiphop%' THEN 'hip-hop' \
WHEN LOWER(tags.tag) LIKE '%rap%' THEN 'rap' \
END AS Genre, \
tids.tid AS tid, Year, \
loudness, \
tempo, \
duration, \
avg_timbre1, \
avg_timbre2, \
avg_timbre3, \
avg_timbre4, \
avg_timbre5, \
avg_timbre6, \
avg_timbre7, \
avg_timbre8, \
avg_timbre9, \
avg_timbre10, \
avg_timbre11, \
avg_timbre12, \
var_timbre1, \
var_timbre2, \
var_timbre3, \
var_timbre4, \
var_timbre5, \
var_timbre6, \
var_timbre7, \
var_timbre8, \
var_timbre9, \
var_timbre10, \
var_timbre11, \
var_timbre12 \
FROM {0}\
WHERE LOWER(tags.tag) LIKE '%rock%' OR LOWER(tags.tag) LIKE '%pop%' OR LOWER(tags.tag) LIKE '%country%' \
OR LOWER(tags.tag) LIKE '%jazz%' OR LOWER(tags.tag) LIKE '%blues%' OR LOWER(tags.tag) LIKE '%electronic%' \
OR LOWER(tags.tag) LIKE '%indie%' OR LOWER(tags.tag) LIKE '%hip-hop%' OR LOWER(tags.tag) LIKE '%hiphop%' OR LOWER(tags.tag) LIKE '%rap%';".format(join_statement)

cursor.execute(query_genres)

query = "SELECT Year, COUNT(DISTINCT Genre) FROM genre_view GROUP BY Year"
df = pd.read_sql_query(query, conn)
df
# Out:
#     Year  COUNT(DISTINCT Genre)
# 0   1922                      1
# 1   1940                      3
# 2   1954                      4
# 3   1955                      3
# 4   1956                      4
# 5   1957                      7
# 6   1958                      6
# 7   1959                      7
# 8   1960                      4
# 9   1961                      6
# 10  1962                      5
# 11  1963                      7
# 12  1964                      7
# 13  1965                      8
# 14  1966                      7
# 15  1967                      8
# 16  1968                      9
# 17  1969                      9
# 18  1970                      9
# 19  1971                      9
# 20  1972                      9
# 21  1973                      9
# 22  1974                      9
# 23  1975                      8
# 24  1976                      9
# 25  1977                      8
# 26  1978                      9
# 27  1979                      9
# 28  1980                      8
# 29  1981                      9
# 30  1982                      9
# 31  1983                      9
# 32  1984                      9
# 33  1985                      8
# 34  1986                      9
# 35  1987                      8
# 36  1988                      9
# 37  1989                      9
# 38  1990                      9
# 39  1991                      9
# 40  1992                      9
# 41  1993                      9
# 42  1994                      9
# 43  1995                      9
# 44  1996                      9
# 45  1997                      9
# 46  1998                      9
# 47  1999                      9
# 48  2000                      9
# 49  2001                      9
# 50  2002                      9
# 51  2003                      9
# 52  2004                      9
# 53  2005                      9
# 54  2006                      9
# 55  2007                      9
# 56  2008                      9
# 57  2009                      9
# 58  2010                      9

# %%
query = "SELECT DISTINCT * FROM genre_view LIMIT 5"
df = pd.read_sql_query(query, conn)
df
# Out:
#    Genre                 tid  Year  loudness    tempo   duration  avg_timbre1  \
# 0  blues  TRCCOOO128F146368B  1993   -13.374  130.488  310.98730    38.683597
# 1    pop  TRCCOOO128F146368B  1993   -13.374  130.488  310.98730    38.683597
# 2    pop  TRCCNMU128F92F9A3D  1981   -17.338  104.491   80.84853    32.188370
# 3   rock  TRCCNMU128F92F9A3D  1981   -17.338  104.491   80.84853    32.188370
# 4  indie  TRCCSHQ128F147746C  1996    -5.657  144.535  161.93261    49.074876
#
#    avg_timbre2  avg_timbre3  avg_timbre4      ...       var_timbre3  \
# 0   -47.915241    -7.940771    -9.449814      ...       1917.667514
# 1   -47.915241    -7.940771    -9.449814      ...       1917.667514
# 2    28.892906   -60.662468    51.020539      ...       2103.732847
# 3    28.892906   -60.662468    51.020539      ...       2103.732847
# 4    50.245527    34.692218    -8.919649      ...       1438.976255
#
#    var_timbre4  var_timbre5  var_timbre6  var_timbre7  var_timbre8  \
# 0  1297.660798   650.394979   612.957790   574.000731   253.479846
# 1  1297.660798   650.394979   612.957790   574.000731   253.479846
# 2  1882.006864   726.805837  1969.979144   346.863482   562.705241
# 3  1882.006864   726.805837  1969.979144   346.863482   562.705241
# 4   554.958456  1018.884008   270.110537   699.658606   233.069496
#
#    var_timbre9  var_timbre10  var_timbre11  var_timbre12
# 0   398.614539    178.531367    177.918005    324.567728
# 1   398.614539    178.531367    177.918005    324.567728
# 2   162.180016    444.764170    482.335899    107.465999
# 3   162.180016    444.764170    482.335899    107.465999
# 4   378.135669    171.480416     79.436274    248.732687
#
# [5 rows x 30 columns]

# %%
minYear = 1954
maxYear = 2010
acoustic_dict = {}

for year in range(minYear,maxYear+1):
    print(year)
    query_acoustic = "SELECT LOWER(g.Genre) AS Genre, \
AVG(loudness) AS AVG_LOUDNESS, \
AVG(tempo) AS AVG_TEMPO, \
AVG(duration) AS AVG_DURATION, \
AVG(avg_timbre1) AS AVG_TIMBRE1, \
AVG(avg_timbre2) AS AVG_TIMBRE2, \
AVG(avg_timbre3) AS AVG_TIMBRE3, \
AVG(avg_timbre4) AS AVG_TIMBRE4, \
AVG(avg_timbre5) AS AVG_TIMBRE5, \
AVG(avg_timbre6) AS AVG_TIMBRE6, \
AVG(avg_timbre7) AS AVG_TIMBRE7, \
AVG(avg_timbre8) AS AVG_TIMBRE8, \
AVG(avg_timbre9) AS AVG_TIMBRE9, \
AVG(avg_timbre10) AS AVG_TIMBRE10, \
AVG(avg_timbre11) AS AVG_TIMBRE11, \
AVG(avg_timbre12) AS AVG_TIMBRE12, \
AVG(var_timbre1) AS AVG_VAR_TIMBRE1, \
AVG(var_timbre2) AS AVG_VAR_TIMBRE2, \
AVG(var_timbre3) AS AVG_VAR_TIMBRE3, \
AVG(var_timbre4) AS AVG_VAR_TIMBRE4, \
AVG(var_timbre5) AS AVG_VAR_TIMBRE5, \
AVG(var_timbre6) AS AVG_VAR_TIMBRE6, \
AVG(var_timbre7) AS AVG_VAR_TIMBRE7, \
AVG(var_timbre8) AS AVG_VAR_TIMBRE8, \
AVG(var_timbre9) AS AVG_VAR_TIMBRE9, \
AVG(var_timbre10) AS AVG_VAR_TIMBRE10, \
AVG(var_timbre11) AS AVG_VAR_TIMBRE11, \
AVG(var_timbre12) AS AVG_VAR_TIMBRE12 \
FROM {0} g \
WHERE g.Year = {1} \
GROUP BY g.Genre ORDER BY Genre;".format('genre_view', str(year))
    df = pd.read_sql_query(query_acoustic, conn)
    acoustic_dict[year] = df
# Out:
# 1954
# 1955
# 1956
# 1957
# 1958
# 1959
# 1960
# 1961
# 1962
# 1963
# 1964
# 1965
# 1966
# 1967
# 1968
# 1969
# 1970
# 1971
# 1972
# 1973
# 1974
# 1975
# 1976
# 1977
# 1978
# 1979
# 1980
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010

# %%
import pickle
input_file = open('acoustic_dict.dat','rb')

acoustic_dict_noRE = pickle.load(input_file) 
input_file.close()
acoustic_dict_noRE[1999]
# Out:
#         Genre  AVG_LOUDNESS   AVG_TEMPO  AVG_DURATION  AVG_TIMBRE1  \
# 0       blues     -8.536417  119.523396    262.112744    44.041691
# 1     country    -12.412387  115.097871    226.392701    40.594720
# 2  electronic     -9.746184  123.947612    302.923461    41.867505
# 3     hip-hop     -7.589750  108.617167    241.257777    43.782269
# 4       indie     -8.324414  122.513121    245.229891    44.620585
# 5        jazz    -11.921600  125.213720    353.335971    39.587756
# 6         pop     -8.428549  125.189632    263.709400    44.154549
# 7         rap     -7.164818  132.248545    309.716800    44.538130
# 8        rock     -7.785214  125.709745    254.101179    45.249337
#
#    AVG_TIMBRE2  AVG_TIMBRE3  AVG_TIMBRE4  AVG_TIMBRE5  AVG_TIMBRE6  \
# 0     0.401681    11.009379     2.081100    -9.162332    -3.058484
# 1   -44.659840    21.530288    -2.991239    -2.053335    -2.342639
# 2    -4.229137   -18.504186     7.360948     3.300601   -11.772693
# 3    16.956211   -24.066006     8.423069     5.028266     9.980125
# 4    -8.373739     0.018415    -1.761145    -6.790704   -11.407960
# 5   -30.261151    -9.512966     1.364981     6.904706   -10.564618
# 6    -2.322248    -1.725728    -0.704076     2.094191   -11.025260
# 7   -16.291426    -3.546023     6.953292     4.505882    -8.066438
# 8     1.223254     6.858183     0.337822    -8.188387    -9.959818
#
#          ...         AVG_VAR_TIMBRE3  AVG_VAR_TIMBRE4  AVG_VAR_TIMBRE5  \
# 0        ...             2384.439677      1639.160088       892.792019
# 1        ...             1769.106161      1529.122695      1017.434379
# 2        ...             2526.279955      2006.899985      1071.228611
# 3        ...             2839.853357      3432.671030      1076.338334
# 4        ...             1894.010035      1477.563743       914.212255
# 5        ...             2999.810429      1720.353163      1116.371541
# 6        ...             2093.455601      1613.855956       893.628649
# 7        ...             2406.014001      1905.416882       833.655283
# 8        ...             2005.759854      1516.970649       916.950703
#
#    AVG_VAR_TIMBRE6  AVG_VAR_TIMBRE7  AVG_VAR_TIMBRE8  AVG_VAR_TIMBRE9  \
# 0       970.211447       642.171116       477.040193       422.780006
# 1       903.171172       676.257396       465.128735       443.823429
# 2      1121.187481       702.692020       690.573764       384.798984
# 3      1976.842585       963.453462       977.771057       453.827148
# 4       792.986805       619.314359       570.301371       350.895033
# 5      1043.284736       816.685430       554.170118       489.920617
# 6       885.583289       631.660860       588.439612       365.093477
# 7      1178.033612       771.595317       696.974340       364.084825
# 8       844.151861       602.289730       529.336973       362.920914
#
#    AVG_VAR_TIMBRE10  AVG_VAR_TIMBRE11  AVG_VAR_TIMBRE12
# 0        313.685329        335.567013        354.886968
# 1        321.710380        306.652013        335.185058
# 2        390.253280        326.210763        292.131543
# 3        589.860168        560.367634        341.753247
# 4        343.910431        264.625147        261.037180
# 5        352.309021        300.529497        391.837711
# 6        341.855053        288.955850        293.736583
# 7        411.910364        353.837003        313.488015
# 8        329.359790        279.220951        281.302909
#
# [9 rows x 28 columns]

# %%
acoustic_dict[1960]
# Out:
#    Genre  AVG_LOUDNESS   AVG_TEMPO  AVG_DURATION  AVG_TIMBRE1  AVG_TIMBRE2  \
# 0  blues    -12.427024  119.694548    157.604989    40.182073   -66.614314
# 1   jazz    -13.389583  110.165917    146.359274    38.547846   -88.631443
# 2    pop    -14.150962  118.958500    152.690283    38.980431   -28.113917
# 3   rock    -10.119040  137.877840    151.867103    44.875156   -10.068696
#
#    AVG_TIMBRE3  AVG_TIMBRE4  AVG_TIMBRE5  AVG_TIMBRE6        ...         \
# 0    24.427477    -0.356422    -1.444050     3.386572        ...
# 1    11.084907    -4.551399   -10.374355     0.716543        ...
# 2    13.427318     1.378150   -12.146588    -0.310159        ...
# 3    51.128450     7.276257    -1.826623    -3.227041        ...
#
#    AVG_VAR_TIMBRE3  AVG_VAR_TIMBRE4  AVG_VAR_TIMBRE5  AVG_VAR_TIMBRE6  \
# 0      2929.308991      2027.083450       875.726334      1047.861955
# 1      2567.327211      2068.213107       939.785736       987.140846
# 2      2273.012924      1639.362753      1081.832845       958.951615
# 3      1458.820468      1092.223938       968.709656       644.176141
#
#    AVG_VAR_TIMBRE7  AVG_VAR_TIMBRE8  AVG_VAR_TIMBRE9  AVG_VAR_TIMBRE10  \
# 0        731.15091       536.432735       506.690958        339.194783
# 1        879.14714       475.649177       477.409571        311.738628
# 2        748.46660       568.440613       473.458285        367.395871
# 3        788.10774       436.976213       415.827777        280.872670
#
#    AVG_VAR_TIMBRE11  AVG_VAR_TIMBRE12
# 0        320.565231        404.947731
# 1        291.947118        419.961490
# 2        268.819929        427.870775
# 3        235.334755        266.336590
#
# [4 rows x 28 columns]

# %%
#Pickle the pivot dictionary
import pickle
output_file = open('acoustic_dict_complete.dat','wb')
pickle.dump(acoustic_dict, output_file)
output_file.close()

# %%
#Acoustic Features All genres

join_statement = 'tid_tag JOIN tids ON (tid_tag.tid=tids.ROWID) JOIN \
tags ON (tags.ROWID=tid_tag.tag) JOIN track_year ON (tids.tid = track_year.tid) JOIN track_acoustic ta ON(tids.tid = ta.track_id)'

#drop_view = "DROP VIEW genre_view;"

#cursor.execute(drop_view)

query_genres = "CREATE VIEW genre_view AS \
SELECT CASE \
WHEN LOWER(tags.tag) LIKE '%rock%' THEN 'rock' \
WHEN LOWER(tags.tag) LIKE '%pop%' THEN 'pop' \
WHEN LOWER(tags.tag) LIKE '%country%' THEN 'country' \
WHEN LOWER(tags.tag) LIKE '%jazz%' THEN 'jazz' \
WHEN LOWER(tags.tag) LIKE '%blues%' THEN 'blues' \
WHEN LOWER(tags.tag) LIKE '%electronic%' THEN 'electronic' \
WHEN LOWER(tags.tag) LIKE '%indie%' THEN 'indie' \
WHEN LOWER(tags.tag) LIKE '%hip.hop%' THEN 'hip-hop' \
WHEN LOWER(tags.tag) LIKE '%rap%' THEN 'rap' \
WHEN LOWER(tags.tag) LIKE '%reggae%' THEN 'reggae' \
WHEN LOWER(tags.tag) LIKE '%latin%' THEN 'latin' \
WHEN LOWER(tags.tag) LIKE '%folk%' THEN 'folk' \
WHEN LOWER(tags.tag) LIKE '%disco%' THEN 'disco' \
WHEN LOWER(tags.tag) LIKE '%metal%' THEN 'metal' \
WHEN LOWER(tags.tag) LIKE '%alternative%' THEN 'alternative' \
WHEN LOWER(tags.tag) LIKE '%dance%' THEN 'dance' \
END AS Genre, \
tids.tid AS tid, Year, \
loudness, \
tempo, \
duration, \
avg_timbre1, \
avg_timbre2, \
avg_timbre3, \
avg_timbre4, \
avg_timbre5, \
avg_timbre6, \
avg_timbre7, \
avg_timbre8, \
avg_timbre9, \
avg_timbre10, \
avg_timbre11, \
avg_timbre12, \
var_timbre1, \
var_timbre2, \
var_timbre3, \
var_timbre4, \
var_timbre5, \
var_timbre6, \
var_timbre7, \
var_timbre8, \
var_timbre9, \
var_timbre10, \
var_timbre11, \
var_timbre12 \
FROM {0}\
WHERE LOWER(tags.tag) LIKE '%rock%' OR LOWER(tags.tag) LIKE '%pop%' OR LOWER(tags.tag) LIKE '%country%' \
OR LOWER(tags.tag) LIKE '%jazz%' OR LOWER(tags.tag) LIKE '%blues%' OR LOWER(tags.tag) LIKE '%electronic%' \
OR LOWER(tags.tag) LIKE '%indie%' OR LOWER(tags.tag) LIKE '%hip.hop%' OR LOWER(tags.tag) LIKE '%rap%' \
OR LOWER(tags.tag) LIKE '%reggae%' OR LOWER(tags.tag) LIKE '%latin%' OR LOWER(tags.tag) LIKE '%folk%' \
OR LOWER(tags.tag) LIKE '%disco%' OR LOWER(tags.tag) LIKE '%metal%' OR LOWER(tags.tag) LIKE '%alternative%' \
OR LOWER(tags.tag) LIKE '%dance%';".format(join_statement)
cursor.execute(query_genres)

minYear = 1954
maxYear = 2010
acoustic_dict_allGenres = {}

for year in range(minYear,maxYear+1):
    print(year)
    query_acoustic = "SELECT LOWER(g.Genre) AS Genre, \
AVG(loudness) AS AVG_LOUDNESS, \
AVG(tempo) AS AVG_TEMPO, \
AVG(duration) AS AVG_DURATION, \
AVG(avg_timbre1) AS AVG_TIMBRE1, \
AVG(avg_timbre2) AS AVG_TIMBRE2, \
AVG(avg_timbre3) AS AVG_TIMBRE3, \
AVG(avg_timbre4) AS AVG_TIMBRE4, \
AVG(avg_timbre5) AS AVG_TIMBRE5, \
AVG(avg_timbre6) AS AVG_TIMBRE6, \
AVG(avg_timbre7) AS AVG_TIMBRE7, \
AVG(avg_timbre8) AS AVG_TIMBRE8, \
AVG(avg_timbre9) AS AVG_TIMBRE9, \
AVG(avg_timbre10) AS AVG_TIMBRE10, \
AVG(avg_timbre11) AS AVG_TIMBRE11, \
AVG(avg_timbre12) AS AVG_TIMBRE12, \
AVG(var_timbre1) AS AVG_VAR_TIMBRE1, \
AVG(var_timbre2) AS AVG_VAR_TIMBRE2, \
AVG(var_timbre3) AS AVG_VAR_TIMBRE3, \
AVG(var_timbre4) AS AVG_VAR_TIMBRE4, \
AVG(var_timbre5) AS AVG_VAR_TIMBRE5, \
AVG(var_timbre6) AS AVG_VAR_TIMBRE6, \
AVG(var_timbre7) AS AVG_VAR_TIMBRE7, \
AVG(var_timbre8) AS AVG_VAR_TIMBRE8, \
AVG(var_timbre9) AS AVG_VAR_TIMBRE9, \
AVG(var_timbre10) AS AVG_VAR_TIMBRE10, \
AVG(var_timbre11) AS AVG_VAR_TIMBRE11, \
AVG(var_timbre12) AS AVG_VAR_TIMBRE12 \
FROM {0} g \
WHERE g.Year = {1} \
GROUP BY g.Genre ORDER BY Genre;".format('genre_view', str(year))
    df = pd.read_sql_query(query_acoustic, conn)
    acoustic_dict_allGenres[year] = df
# Out:
# 1954
# 1955

# %%
import pickle
output_file = open('acoustic_dict_allGenres.dat','wb')
pickle.dump(acoustic_dict_allGenres, output_file)
output_file.close()
