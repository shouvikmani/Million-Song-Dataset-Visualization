# %%
import sqlite3
import pandas as pd

# %%
#Connect to Database
DBName = '../../MillionSongSubset/lastfm_tags.db'
conn=sqlite3.connect(DBName)

# %%
#Get the top 5 rows in the database
join_statement = 'tid_tag JOIN tids ON (tid_tag.tid=tids.ROWID) JOIN \
tags ON (tags.ROWID=tid_tag.tag) JOIN track_year ON (tids.tid = track_year.tid)'

query = "SELECT tids.tid, song_name, artist_name, Year, tags.tag FROM {0} LIMIT 5;".format(join_statement)
df = pd.read_sql_query(query, conn)
df
# Out:
#                   tid      song_name         artist_name  Year  \
# 0  TRCCCYE12903CFF0E9  Brandenburger            The Nice  1991
# 1  TRCCCYE12903CFF0E9  Brandenburger            The Nice  1991
# 2  TRCCCJT128F429FFF6  Bonjour ca va  Middle Of The Road  1999
# 3  TRCCCJT128F429FFF6  Bonjour ca va  Middle Of The Road  1999
# 4  TRCCCJT128F429FFF6  Bonjour ca va  Middle Of The Road  1999
#
#                   tag
# 0        classic rock
# 1    Progressive rock
# 2                 pop
# 3                 70s
# 4  Middle of the road

# %%
#Get the top 20 genres in 1955
query = "SELECT tags.tag, COUNT(DISTINCT tids.tid) AS NumSongs, Year \
FROM {0}\
WHERE Year = 1955 \
GROUP BY tags.tag \
ORDER BY NumSongs DESC LIMIT 20;".format(join_statement)

df = pd.read_sql_query(query, conn)
df
# Out:
#                  tag  NumSongs  Year
# 0             oldies       119  1955
# 1               jazz       111  1955
# 2                50s        98  1955
# 3                pop        68  1955
# 4           american        56  1955
# 5     easy listening        52  1955
# 6              blues        49  1955
# 7               1955        48  1955
# 8     male vocalists        48  1955
# 9               rock        48  1955
# 10  rhythm and blues        47  1955
# 11             swing        47  1955
# 12     Rock and Roll        45  1955
# 13             1950s        39  1955
# 14              50's        38  1955
# 15       rock n roll        38  1955
# 16               60s        37  1955
# 17      classic rock        35  1955
# 18          crooners        35  1955
# 19             vocal        33  1955

# %%
#Get the top 20 genres in 1995
query = "SELECT tags.tag, COUNT(DISTINCT tids.tid) AS NumSongs, Year \
FROM {0}\
WHERE Year = 1995 \
GROUP BY tags.tag \
ORDER BY NumSongs DESC LIMIT 20;".format(join_statement)

df = pd.read_sql_query(query, conn)
df
# Out:
#                   tag  NumSongs  Year
# 0                rock      2222  1995
# 1                 90s      1846  1995
# 2                 pop      1212  1995
# 3         alternative      1199  1995
# 4           favorites       849  1995
# 5          electronic       834  1995
# 6    female vocalists       821  1995
# 7                1995       811  1995
# 8    alternative rock       796  1995
# 9               indie       786  1995
# 10              dance       601  1995
# 11               Love       596  1995
# 12           chillout       578  1995
# 13               jazz       552  1995
# 14              metal       532  1995
# 15        electronica       510  1995
# 16            Awesome       503  1995
# 17          beautiful       497  1995
# 18              blues       489  1995
# 19  singer-songwriter       472  1995

# %%
#Get number of songs by genre
query = "SELECT tags.tag, COUNT(DISTINCT tids.tid) AS NumSongs \
FROM {0} \
GROUP BY tags.tag \
ORDER BY NumSongs DESC LIMIT 20;".format(join_statement)

df = pd.read_sql_query(query, conn)
df
# Out:
#                   tag  NumSongs
# 0                rock     85671
# 1                 pop     58687
# 2         alternative     48722
# 3               indie     42005
# 4          electronic     38410
# 5    female vocalists     35865
# 6           favorites     34934
# 7                Love     30279
# 8                 00s     27558
# 9               dance     27337
# 10   alternative rock     26472
# 11          beautiful     25701
# 12  singer-songwriter     24206
# 13           chillout     23452
# 14              metal     23304
# 15     male vocalists     23214
# 16               jazz     23102
# 17            Awesome     22885
# 18         indie rock     21661
# 19             Mellow     21218

# %%
#Get number of songs that are both pop and rock by year
query_pop = "SELECT tids.tid AS tid, Year FROM {0} WHERE tags.tag = 'pop'".format(join_statement)
query_rock = "SELECT tids.tid AS tid, Year FROM {0} WHERE tags.tag = 'rock'".format(join_statement)

query_poprock = "SELECT p.Year, COUNT(DISTINCT p.tid) AS NumPopRock FROM ({0}) p JOIN ({1}) r USING (tid) GROUP BY p.Year;".format(query_pop, query_rock)

df = pd.read_sql_query(query_poprock, conn)
df
# Out:
#     p.Year  NumPopRock
# 0     1947           2
# 1     1952           4
# 2     1954          10
# 3     1955          34
# 4     1956          50
# 5     1957         105
# 6     1958         133
# 7     1959          84
# 8     1960          50
# 9     1961          58
# 10    1962          78
# 11    1963         148
# 12    1964         169
# 13    1965         151
# 14    1966         271
# 15    1967         310
# 16    1968         298
# 17    1969         283
# 18    1970         331
# 19    1971         201
# 20    1972         309
# 21    1973         304
# 22    1974         280
# 23    1975         247
# 24    1976         261
# 25    1977         308
# 26    1978         364
# 27    1979         431
# 28    1980         399
# 29    1981         393
# 30    1982         435
# 31    1983         457
# 32    1984         531
# 33    1985         468
# 34    1986         466
# 35    1987         492
# 36    1988         495
# 37    1989         472
# 38    1990         423
# 39    1991         452
# 40    1992         476
# 41    1993         549
# 42    1994         524
# 43    1995         641
# 44    1996         646
# 45    1997         620
# 46    1998         605
# 47    1999         788
# 48    2000         711
# 49    2001         930
# 50    2002         950
# 51    2003        1404
# 52    2004        1548
# 53    2005        1899
# 54    2006        1793
# 55    2007        2117
# 56    2008        1447
# 57    2009         917
# 58    2010         217

# %%
#Get number of songs that are both country and rock by year
query_country = "SELECT tids.tid AS tid, Year FROM {0} WHERE tags.tag = 'country'".format(join_statement)
query_rock = "SELECT tids.tid AS tid, Year FROM {0} WHERE tags.tag = 'rock'".format(join_statement)

query_countryrock = "SELECT c.Year, COUNT(DISTINCT c.tid) AS NumCountryRock FROM ({0}) c JOIN ({1}) r USING (tid) GROUP BY c.Year;".format(query_country, query_rock)

df = pd.read_sql_query(query_countryrock, conn)
df
# Out:
#     c.Year  NumCountryRock
# 0     1949               1
# 1     1953               1
# 2     1954               6
# 3     1955               2
# 4     1956              13
# 5     1957              33
# 6     1958              50
# 7     1959              15
# 8     1960              17
# 9     1961               4
# 10    1962               5
# 11    1963              33
# 12    1964              12
# 13    1965              15
# 14    1966              16
# 15    1967              28
# 16    1968              51
# 17    1969              94
# 18    1970              80
# 19    1971              77
# 20    1972              55
# 21    1973              75
# 22    1974              59
# 23    1975              22
# 24    1976              36
# 25    1977              24
# 26    1978              17
# 27    1979              12
# 28    1980              20
# 29    1981              18
# 30    1982              25
# 31    1983              13
# 32    1984              21
# 33    1985              33
# 34    1986              34
# 35    1987              32
# 36    1988              61
# 37    1989              24
# 38    1990              62
# 39    1991              32
# 40    1992              48
# 41    1993              48
# 42    1994              46
# 43    1995              55
# 44    1996              99
# 45    1997              66
# 46    1998              81
# 47    1999              58
# 48    2000              62
# 49    2001              77
# 50    2002             124
# 51    2003             137
# 52    2004             148
# 53    2005             190
# 54    2006             181
# 55    2007             243
# 56    2008             109
# 57    2009              61
# 58    2010              14

# %%
#Pivot table of how many songs are shared ("connections) per genre

query_genres = "SELECT tags.tag AS Genre, tids.tid AS tid \
FROM {0} \
WHERE tags.tag IN ('rock','pop','country','jazz','blues')".format(join_statement)

query_pivot = "SELECT g.Genre AS Genre, \
SUM(CASE a.Genre WHEN 'blues' THEN 1 ELSE 0 END) AS Blues, \
SUM(CASE a.Genre WHEN 'country' THEN 1 ELSE 0 END) AS Country, \
SUM(CASE a.Genre WHEN 'jazz' THEN 1 ELSE 0 END) AS Jazz, \
SUM(CASE a.Genre WHEN 'pop' THEN 1 ELSE 0 END) AS Pop, \
SUM(CASE a.Genre WHEN 'rock' THEN 1 ELSE 0 END) AS Rock \
FROM ({0}) g JOIN ({0}) a ON(g.tid = a.tid) \
GROUP BY g.Genre;".format(query_genres, join_statement)

df = pd.read_sql_query(query_pivot, conn)
df
# Out:
#      Genre  Blues  Country   Jazz    Pop   Rock
# 0    blues  15479     1165   3074   3337   6626
# 1  country   1165    11683    275   2466   3075
# 2     jazz   3074      275  23102   4510   3841
# 3      pop   3337     2466   4510  58687  29539
# 4     rock   6626     3075   3841  29539  85671
